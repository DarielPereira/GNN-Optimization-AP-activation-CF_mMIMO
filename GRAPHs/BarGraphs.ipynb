# %%
import matplotlib.pyplot as plt
import numpy as np
from functionsUtils import load_results
#
plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')

# %%
# Data
alternatives = ['Q-random', 'Best-gain individual APs', 'Best individual APs', 'CPU-local ES', 'CPU-local SG', '(Succ.) CPU-local SG', '(Succ.) CPU-local ES', 'Sequential Greedy']
values = [82.4948, 86.9836, 99.8377, 100.1261, 100.1932, 100.9010, 100.9854, 101.4560]  # Replace with your values

fig, ax = plt.subplots()
plt.grid(linestyle='--', alpha=0.5)

spacing = 10 # Spacing factor
x_positions = np.arange(len(alternatives)) * spacing
# Create the bar chart
plt.bar(x_positions, values, width=8, color=['black', 'springgreen', 'green', 'red', 'skyblue', 'blue', 'lightcoral', 'fuchsia'])

plt.xticks(x_positions, alternatives, rotation=70, fontsize=12)
plt.ylim([80, 105])

# Add labels and title
plt.ylabel('Average sum-rate [bits/s/Hz]', fontsize=12)

# Annotate values on bars
for i, value in enumerate(values):
    plt.text(x_positions[i], value + 1, str(value), ha='center', fontsize=10)

# Show the plot
plt.tight_layout()
plt.draw()
plt.show()

image_format = 'png' # e.g .png, .svg, etc.
image_name = 'AveSE_BarGraph_MediumSetups.png'
fig.savefig(image_name, format=image_format, dpi=400)

# %%
# Data
alternatives = ['Q-random', 'CPU-local ES', 'CPU-local SG', 'Best individual APs', '(Succ.) CPU-local ES', '(Succ.) CPU-local SG', 'Sequential Greedy -Estimation-']
values = [111.7172, 122.2961, 122.9315, 123.1983, 123.1683, 123.8727, 124]  # Replace with your values

fig, ax = plt.subplots()
plt.grid(linestyle='--', alpha=0.5)

spacing = 10 # Spacing factor
x_positions = np.arange(len(alternatives)) * spacing
# Create the bar chart
plt.bar(x_positions, values, width=8, color=['black', 'red', 'skyblue', 'green', 'lightcoral', 'blue', 'fuchsia'])

plt.xticks(x_positions, alternatives, rotation=70, fontsize=12)
plt.ylim([100, 130])

# Add labels and title
plt.ylabel('Average sum-rate [bits/s/Hz]', fontsize=12)

# Annotate values on bars
for i, value in enumerate(values):
    plt.text(x_positions[i], value + 1, str(value), ha='center', fontsize=10)

# Show the plot
plt.tight_layout()
plt.draw()
plt.show()

image_format = 'png' # e.g .png, .svg, etc.
image_name = 'AveSE_BarGraph_largeSetups.png'
fig.savefig(image_name, format=image_format, dpi=400)

# %%
# Data
alternatives = ['Q-random', 'Best individual APs', 'CPU-local ES', 'CPU-local SG','(Succ.) CPU-local SG','(Succ.) CPU-local ES', 'Sequential Greedy']
values = [39.7576, 51.0572, 53.1731, 53.1831,  53.8660,  54.1088, 54.1757]  # Replace with your values

fig, ax = plt.subplots()
plt.grid(linestyle='--', alpha=0.5)

spacing = 10 # Spacing factor
x_positions = np.arange(len(alternatives)) * spacing
# Create the bar chart
plt.bar(x_positions, values, width=8, color=['black', 'green', 'skyblue', 'lightcoral', 'red', 'blue', 'firebrick'])

plt.xticks(x_positions, alternatives, rotation=70, fontsize=12)
plt.ylim([35, 58])

# Add labels and title
plt.ylabel('Average sum-rate [bits/s/Hz]', fontsize=12)

# Annotate values on bars
for i, value in enumerate(values):
    plt.text(x_positions[i], value + 1, str(value), ha='center', fontsize=10)

# Show the plot
plt.tight_layout()
plt.draw()
plt.show()

image_format = 'png' # e.g .png, .svg, etc.
image_name = 'AveSE_BarGraph.png'
fig.savefig(image_name, format=image_format, dpi=400)

# %%
import math

T = 8
# Q = 4

combinaciones = [math.comb(T, q) for q in range(1, T+1)]
print(combinaciones)

secuencias = [(T - (T-q) + 1) * ((T-q) + T) // 2 for q in range(0, T)]
print(secuencias)

# Plot the results
fig, ax = plt.subplots(2, 1, figsize=(10, 8))

# Plot combinations
ax[0].bar(range(1, T+1), combinaciones, color='blue')
ax[0].set_title('Combinations')
ax[0].set_xlabel('q')
ax[0].set_ylabel('Combinations')
ax[0].set_ylim([0, 80])

# Plot sequences
ax[1].bar(range(0, T), secuencias, color='green')
ax[1].set_title('Sequences')
ax[1].set_xlabel('q')
ax[1].set_ylabel('Sequences')
ax[1].set_ylim([0, 80])


# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# [8, 28, 56, 70, 56, 28, 8, 1]
# [8, 15, 21, 26, 30, 33, 35, 36]

# %%
np.histogram(DCC_nbrServingAPs, bins=6)
# Out:
# (array([ 20,   8,  48, 104, 108, 112], dtype=int64),
#  array([1., 2., 3., 4., 5., 6., 7.]))
